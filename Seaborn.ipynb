# %%
## Seaborn - used for more advanced and complex data visualization

# %%
# !pip install seaborn

# %%
# importing seaborn library
import seaborn as sns

# %%
# loading dataset
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
## Scatter Plot 
import matplotlib.pyplot as plt 
sns.scatterplot(x = "total_bill" , y = "tip" , data = tips)
plt.title("Scatter Plot of total_bill vs tip")
plt.show()

# %%
sns.scatterplot(x = "tip" , y = "size" , data = tips)
plt.show()

# %%
## Line Plot 
sns.lineplot(x = "size" , y = "total_bill" , data =tips)
plt.title("Line pot")
plt.show()

# %%
sns.lineplot(x = "size" , y = "tip" , data = tips)
plt.show()

# %%
## Categorical Plots

# Bar Plot
sns.barplot(x = "day" , y = "total_bill" , data = tips)
plt.title("Bar plot of total bills per/by day")
plt.show()

# %%
sns.barplot(x = "sex" , y = "tip" , data = tips)
plt.show()

# %%
## Box Plot- It gives 0 , 25 , 50 , 75 , 100 percentile of data and also give outliers 
sns.boxplot(x = "day" , y = "total_bill" , data = tips )
plt.show()

# %%
sns.boxplot(x = "sex" , y = "tip" , data = tips)
plt.show()

# %%
# Violin plot - for distribution of data 
sns.violinplot(x = "day" , y = "total_bill" , data = tips)
plt.show()

# %%
sns.violinplot(x = "sex" , y ="size" , data = tips)
plt.show()

# %%
## histogram 
sns.histplot(tips["total_bill"] , bins = 10 , kde = True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
## kde ( kernel density estimator ) plot
sns.kdeplot(tips["total_bill"] , shade = True , fill = True)
plt.show()
# Out:
# C:\Users\sahan\AppData\Local\Temp\ipykernel_15312\4203917062.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(tips["total_bill"] , shade = True , fill = True)

# %%
sns.histplot(tips["tip"],bins = 5 ,kde=True)
plt.show()

# %%
## pair plot - relationship between all the variables ( only numerical data )
sns.pairplot(tips)

# %%
# Heat Map
corr = tips[["total_bill", "tip" , "size"]].corr()
corr
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
## change in tip is 0.675 with respect to 1.00 unit total_bill and so on

# %%
sns.heatmap(corr,annot = True)
# Out:
# <Axes: >

# %%
sns.heatmap(corr,annot = True , cmap= "coolwarm")
# Out:
# <Axes: >

# %%
## Plot total sales by product 
import pandas as pd
df = pd.read_csv("random_sales_data.csv")
df.head()
# Out:
#            Date Category  Value   Product   Sales Region
# 0    2023-01-22        B   55.0  product2  715.31  north
# 1    2023-01-23        B   92.0  product3  421.10   east
# 2    2023-01-24        B   69.0  product3  501.01   west
# 3    2023-01-25        C   15.0  product3  811.65  north
# 4    2023-01-26        A   61.0  product3  831.55  south

# %%
sns.barplot(x = "Product" , y = "Sales" , data = df ) # estimator = sum ) # estimator is method of using aggregate functions
# Out:
# <Axes: xlabel='Product', ylabel='Sales'>

# %%
sns.boxplot(x = "Category" , y = "Sales" , data = df)
# Out:
# <Axes: xlabel='Category', ylabel='Sales'>
